# %% [markdown]
# # Tutorial "Ciencia de datos: Aprendiendo lo básico"
#
# ## Workshop CIO Update 2016
# ## Autor: Roberto Muñoz
#
# En este tutorial haremos una revisión de los procesos de exploración, análisis y visualización de datos los cuales son comúnes en el campo del Data Science.
#
# Este tutorial fue construido usando el lenguaje Python 3 y la aplicación web Jupyter.
#
# Usaremos los siguientes datasets,
# - Terremotos ocurridos durante la última década en el mundo y publicados por el USGS
# - Uso del transporte
#
# Los principales paquetes y librerías de Python que se usan en el campo del Data Science son los siguientes,
#
# #### NumPy
#
# Website: [http://www.numpy.org](http://www.numpy.org)
#
# NumPy is probably the most fundamental package for efficient scientific computing in Python through linear algebra routines. One of NumPy's major strength is that most operations are implemented as C/C++ and FORTRAN code for efficiency. At its core, NumPy works with multi-dimensional array objects that support broadcasting and lead to efficient, vectorized code.
#
# #### SciPy
#
# Website: [http://scipy.org/scipylib/index.html](http://scipy.org/scipylib/index.html)
#
# SciPy is a considered to be one of the core packages for scientific computing routines. As a useful expansion of the NumPy core functionality, it contains a broad range of functions for linear algebra, interpolation, integration, clustering, and [many more](http://docs.scipy.org/doc/scipy/reference/index.html).
#
#
# #### Pandas
#
# Website: [http://pandas.pydata.org](http://pandas.pydata.org)
#
# Pandas is a library for operating with table-like structures. It comes with a powerful DataFrame object, which is a multi-dimensional array object for efficient numerical operations similar to NumPy's *ndarray* with additional functionalities.
#
# #### Scikit-learn
#
# Website: [http://scikit-learn.org/stable/](http://scikit-learn.org/stable/)
#
# Scikit-learn is is probably the most popular general machine library for Python. It includes a broad range of different classifiers, cross-validation and other model selection methods, dimensionality reduction techniques, modules for regression and clustering analysis, and a useful data-preprocessing module.
#
# #### Matplotlib
#
# Website: [http://matplotlib.org](http://matplotlib.org)
#
# Matplotlib is Python's most popular and comprehensive plotting library that is especially useful in combination with NumPy/SciPy.
#
# #### Bokeh
#
# Website: [http://bokeh.pydata.org](http://bokeh.pydata.org)
#
# Bokeh is a plottling library that is focussed on aesthetic layouts and interactivity to produce high-quality plots for web browsers.

# %% [markdown]
# ---
# #### 1. Partimos importando Numpy, Pandas y Matplotlib

# %%
import numpy as np
import pandas as pd
import pylab
import matplotlib.pyplot as plt

# %matplotlib inline

params = {'backend': 'agg',
'axes.labelsize': 16,
'font.size': 16,
'legend.fontsize': 14,
'xtick.labelsize': 14,
'ytick.labelsize': 14,
'text.usetex': False,
'figure.figsize': [10,6]}
pylab.rcParams.update(params)
#matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# %% [markdown]
# Visitamos la página web del United States Geological Service (USGS)
#
# Hacemos una busqueda en el link http://earthquake.usgs.gov/earthquakes/search/
#
# ![title](data/USGS%20earthquake%20webpage.jpg)
#
# ![title](data/USGS%20earthquake%20search.jpg)

# %% [markdown]
# ---
# #### Leemos el archivos CSV que descargamos desde el sitio web de la USGS. Usamos la libreria Pandas para leer y cargar en memoria los datos.

# %%
data_file='data/USGS earthquake 2006-2016.csv'
earthquake=pd.read_csv(data_file,header=0,sep=',')
earthquake['time']=pd.to_datetime(earthquake['time'], errors='coerce')

# %% [markdown]
# #### Los datos fueron cargados en una variable llamada earthquake. El primer paso en la exploración de los datos es desplegar el encabezado.

# %%
earthquake.head()
# Out:
#                      time  latitude  longitude  depth  mag magType    nst  \
# 0 2006-01-01 03:21:39.210    13.951    146.358   36.7  4.6      mb   24.0
# 1 2006-01-01 07:11:57.010    31.394    140.131   10.0  5.6     mwb  143.0
# 2 2006-01-01 08:47:13.350     4.735     95.144   51.5  5.5     mwb  276.0
# 3 2006-01-01 09:43:14.810    11.839    -71.193   69.0  5.1     mwc  189.0
# 4 2006-01-01 10:26:30.200   -19.133   -173.500   44.2  4.9      mb   21.0
#
#      gap  dmin   rms    ...                      updated  \
# 0  101.1   NaN  0.99    ...     2014-11-07T01:28:00.144Z
# 1   98.9   NaN  1.35    ...     2015-05-13T18:53:50.000Z
# 2   25.9   NaN  0.73    ...     2015-06-30T16:59:03.179Z
# 3   36.3   NaN  0.87    ...     2015-02-11T17:18:12.000Z
# 4  129.0   NaN  1.24    ...     2014-11-07T01:28:01.091Z
#
#                          place        type horizontalError depthError  \
# 0       Mariana Islands region  earthquake             NaN       23.3
# 1    Izu Islands, Japan region  earthquake             NaN        NaN
# 2  northern Sumatra, Indonesia  earthquake             NaN        NaN
# 3           Golfo de Venezuela  earthquake             NaN        NaN
# 4                        Tonga  earthquake             NaN       56.4
#
#    magError  magNst    status  locationSource magSource
# 0       NaN     2.0  reviewed              us        us
# 1       NaN     NaN  reviewed              us        us
# 2       NaN     NaN  reviewed              us        us
# 3       NaN     NaN  reviewed              us       hrv
# 4       NaN     6.0  reviewed              us        us
#
# [5 rows x 22 columns]

# %% [markdown]
# #### También podemos mostrar las columnas que contiene la tabla y el número de elementos

# %%
print("Columnas de earthquake: ", earthquake.columns.values, "\n")
print("Numero de elementos: ", len(earthquake.index), "\n")
# Out:
# Columnas de earthquake:  ['time' 'latitude' 'longitude' 'depth' 'mag' 'magType' 'nst' 'gap' 'dmin'
#  'rms' 'net' 'id' 'updated' 'place' 'type' 'horizontalError' 'depthError'
#  'magError' 'magNst' 'status' 'locationSource' 'magSource']
#
# Numero de elementos:  76855

# %% [markdown]
# #### Las visualizaciones y gráficos nos pueden ayudar enormemente en la exploración de los datos. Un tipo de gráfico muy útil corresponde al histograma. A Continuación usamos un histograma para mostrar la distribución del número de terremotos como función de la magnitud.

# %%
#fig, ax = plt.subplots(figsize=(10,6))
ax=earthquake['mag'].hist(bins=20)
ax.set_yscale('log')
ax.set_xlabel('Magnitud')
ax.set_ylabel('Nº de terremotos')

# %% [markdown]
# #### Del histograma podemos ver que la distribución del número de terremotos sigue una ley de potencia y que el número disminuye a medida que aumenta la intensidad del terremoto.
#
# #### Digamos que nos llama la atención el último bin del gráfico y queremos imprimir en pantalla cuáles fueron esos terremotos. Usamos la función query de pandas e imprimos los terremotos con magnitud mayor a 8.5.

# %%
earthquake.query('mag>8.5')
# Out:
#                          time  latitude  longitude  depth  mag magType    nst  \
# 27645 2010-02-27 06:34:11.530   -36.122    -72.898   22.9  8.8     mwc  454.0
# 35261 2011-03-11 05:46:24.120    38.297    142.373   29.0  9.0     mww  541.0
# 45681 2012-04-11 08:38:36.720     2.327     93.063   20.0  8.6     mww  499.0
#
#         gap  dmin   rms    ...                      updated  \
# 27645  17.8   NaN  1.09    ...     2016-05-03T15:30:47.329Z
# 35261   9.5   NaN  1.16    ...     2016-02-11T22:47:50.084Z
# 45681  16.6   NaN  1.33    ...     2016-03-02T18:30:13.189Z
#
#                                         place        type horizontalError  \
# 27645                 offshore Bio-Bio, Chile  earthquake             NaN
# 35261    near the east coast of Honshu, Japan  earthquake             NaN
# 45681  off the west coast of northern Sumatra  earthquake             NaN
#
#       depthError  magError  magNst    status  locationSource magSource
# 27645        9.2       NaN     NaN  reviewed              us        us
# 35261        NaN       NaN     NaN  reviewed              us        us
# 45681        NaN       NaN     NaN  reviewed              us        us
#
# [3 rows x 22 columns]

# %% [markdown]
# #### Supongamos que queremos mostrar la evolución temporal de los terremotos. Para ello, usaremos la columna 'time' de la tabla y haremos un histograma para mostrar el número de terremotos como función de la fecha.

# %%
ax=earthquake['time'].hist(bins=30)
ax.set_xlabel('Fecha')
ax.set_ylabel('Nº de terremotos')

# %% [markdown]
# #### Algunas veces queremos ir al detalle y mostrar el número de terremotos por cada año y mes. La tabla original solo tiene la columna 'time' para la fecha y hora del evento. Para facilitar el análisis, crearemos una columna para el año (year) y otra para el mes (month) basadas en la columna de la fecha (time).

# %%
earthquake['year']=earthquake['time'].dt.year
earthquake['month']=earthquake['time'].dt.month

# %% [markdown]
# #### Luego simplemente usamos la función groupby de Pandas para agrupar los terremotos por año y mes. En este caso, estamos interesados en contar el numero de terremotos y por ellos usaremos la función count.

# %%
earthquake_count=earthquake.groupby(by=['year','month'])['mag'].count()
print(earthquake_count)
# Out:
# year  month
# 2006  1         442
#       2         440
#       3         619
#       4         598
#       5         691
#       6         511
#       7         734
#       8         532
#       9         434
#       10        556
#       11        997
#       12        515
# 2007  1         703
#       2         484
#       3         554
#       4         856
#       5         463
#       6         472
#       7         538
#       8         688
#       9         784
#       10        588
#       11        572
#       12        562
# 2008  1         446
#       2         499
#       3         528
#       4         555
#       5         709
#       6         571
#                ...
# 2014  2         553
#       3         664
#       4        1028
#       5         682
#       6         774
#       7         668
#       8         632
#       9         580
#       10        743
#       11        743
#       12        606
# 2015  1         553
#       2         519
#       3         520
#       4         524
#       5         710
#       6         515
#       7         601
#       8         542
#       9         897
#       10        525
#       11        637
#       12        619
# 2016  1         542
#       2         503
#       3         465
#       4         692
#       5         530
#       6         515
#       7         289
# Name: mag, dtype: int64

# %% [markdown]
# #### Ahora procedemos a graficar la distribución del número de tererremotos por año y mes. Usamos la variable earthquake_count que contiene las cuentas de terremotos por año y mes.

# %%
fig, ax = plt.subplots(figsize=(16,6))
ax=earthquake_count.plot(kind="bar")
ax.set_xlabel('Año y mes')
ax.set_ylabel('Nº de terremotos')

# %% [markdown]
# #### Nuestra primear observación de este gráfico es que es muy difícil de leer. La razóm se debe a que estamos tratando de graficar mucha información usando un gráfico de barras y por ello la información del eje X aparece tan apretada.
#
# #### Una solución sería graficar un conjunto de datos más pequeños, digamos solamente los terremotos del año 2011. La otra solución es hacer un gráfico de barras donde acumulemos los terremotos por mes. Para ello usaremos las funciones unstrack de Pandas.

# %%
fig, ax = plt.subplots(figsize=(16,6))
earthquake_count.unstack().plot(ax=ax, kind='bar',stacked=True,title="Distribución de terremotos por año y mes")
ax.set_xlabel("Año")
ax.set_ylabel("Nº de terremotos")
ax.legend(["Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic"], bbox_to_anchor=(0., 1.1, 1., .102), loc=3, ncol=12, mode="expand", borderaxespad=0.)

# %% [markdown]
# #### Este último gráfico de barras acumulado es útil para visualizar la información. Por ejemplo, podemos notar que el 2011 corresponde al año con más terremotos y que para el año 2016 solo tenemos datos hasta julio.
#
# #### Para el año 2011 podemos notar que el mes de marzo concentra la mayoría de los terremotos. Usaremos la función query para buscar terremotos del año 2011 y luego groupby para agrupar por año y mes.

# %%
earthquake.query('year==2011').groupby([earthquake['year'],earthquake['month']])['mag'].count()
# Out:
# year  month
# 2011  1         660
#       2         482
#       3        2401
#       4         833
#       5         782
#       6         668
#       7         840
#       8         638
#       9         527
#       10        624
#       11        570
#       12        551
# Name: mag, dtype: int64

# %% [markdown]
# #### Algo que quizás nos pueda interesar es saber en qué lugar ocurrieron los terremotos de marzo del 2011. Para ello podriamos usar la columna place de la tabla

# %%
earthquake_query=earthquake.query('year==2011 & month==3').groupby(by=['place'])['mag'].count().sort_values(ascending=False)
print(earthquake_query)
print("\nNumero de registros: ", len(earthquake_query.index))
# Out:
# place
# off the east coast of Honshu, Japan                      1131
# near the east coast of Honshu, Japan                      781
# eastern Honshu, Japan                                      30
# Vanuatu                                                    21
# off the east coast of the Kamchatka Peninsula, Russia      18
# Gulf of California                                         15
# Tonga                                                      15
# Fiji region                                                14
# South Sandwich Islands region                              14
# Bonin Islands, Japan region                                13
# New Britain region, Papua New Guinea                       10
# south of the Fiji Islands                                  10
# Mindanao, Philippines                                       9
# offshore Valparaiso, Chile                                  8
# northern Mid-Atlantic Ridge                                 7
# Mid-Indian Ridge                                            7
# Kuril Islands                                               7
# Ascension Island region                                     6
# southern Sumatra, Indonesia                                 6
# Hindu Kush region, Afghanistan                              5
# southwestern Ryukyu Islands, Japan                          5
# Izu Islands, Japan region                                   5
# Myanmar                                                     5
# Luzon, Philippines                                          5
# Kepulauan Talaud, Indonesia                                 5
# Bougainville region, Papua New Guinea                       5
# Ryukyu Islands, Japan                                       5
# Kermadec Islands region                                     5
# southern Iran                                               5
# South Island of New Zealand                                 4
#                                                          ...
# offshore Northern California                                1
# south of Bali, Indonesia                                    1
# south of Tonga                                              1
# southwest of Sumatra, Indonesia                             1
# Volcano Islands, Japan region                               1
# Vanuatu region                                              1
# Valparaiso, Chile                                           1
# Turkey-Iran border region                                   1
# Lake Albert region, Uganda                                  1
# Maule, Chile                                                1
# Mauritius - Reunion region                                  1
# Mona Passage                                                1
# Myanmar-China border region                                 1
# Nicobar Islands, India region                               1
# Pagan region, Northern Mariana Islands                      1
# Panama-Costa Rica border region                             1
# Potosi, Bolivia                                             1
# Sakhalin, Russia                                            1
# Salta, Argentina                                            1
# Samoa Islands region                                        1
# Santa Cruz Islands region                                   1
# Shikoku, Japan                                              1
# South Africa                                                1
# South Indian Ocean                                          1
# Sulawesi, Indonesia                                         1
# Sumba region, Indonesia                                     1
# Taiwan                                                      1
# Tajikistan                                                  1
# Trinidad region, Trinidad and Tobago                        1
# 7km NW of The Geysers, CA                                   1
# Name: mag, dtype: int64
#
# Numero de registros:  161

# %% [markdown]
# #### Podemos notar que más del 50% de los terremotos del mes de marzo del 2011 ocurrieron en Japón

# %%
from nltk.tag import StanfordNERTagger
import operator
import re

stanford = StanfordNERTagger("english.muc.7class.distsim.crf.ser.gz")

# %%
for i, text in enumerate(earthquake_query.index.values):
    print("Registro: ",i, " - Place: ", text)
    text_split=stanford.tag(text.split())
    print(text_split)
# Out:
# Registro:  0  - Place:  off the east coast of Honshu, Japan
# [('off', 'O'), ('the', 'O'), ('east', 'O'), ('coast', 'O'), ('of', 'O'), ('Honshu,', 'O'), ('Japan', 'LOCATION')]
# Registro:  1  - Place:  near the east coast of Honshu, Japan
# [('near', 'O'), ('the', 'O'), ('east', 'O'), ('coast', 'O'), ('of', 'O'), ('Honshu,', 'O'), ('Japan', 'LOCATION')]
# Registro:  2  - Place:  eastern Honshu, Japan
# [('eastern', 'O'), ('Honshu,', 'O'), ('Japan', 'LOCATION')]
# Registro:  3  - Place:  Vanuatu
# [('Vanuatu', 'LOCATION')]
# Registro:  4  - Place:  off the east coast of the Kamchatka Peninsula, Russia
# [('off', 'O'), ('the', 'O'), ('east', 'O'), ('coast', 'O'), ('of', 'O'), ('the', 'O'), ('Kamchatka', 'LOCATION'), ('Peninsula,', 'LOCATION'), ('Russia', 'LOCATION')]
# Registro:  5  - Place:  Gulf of California
# [('Gulf', 'O'), ('of', 'O'), ('California', 'LOCATION')]
# Registro:  6  - Place:  Tonga
# [('Tonga', 'LOCATION')]
# Registro:  7  - Place:  Fiji region
# [('Fiji', 'LOCATION'), ('region', 'O')]
# Registro:  8  - Place:  South Sandwich Islands region
# [('South', 'LOCATION'), ('Sandwich', 'LOCATION'), ('Islands', 'LOCATION'), ('region', 'O')]
# Registro:  9  - Place:  Bonin Islands, Japan region
# [('Bonin', 'O'), ('Islands,', 'O'), ('Japan', 'LOCATION'), ('region', 'O')]
# Registro:  10  - Place:  New Britain region, Papua New Guinea
# [('New', 'O'), ('Britain', 'LOCATION'), ('region,', 'O'), ('Papua', 'LOCATION'), ('New', 'LOCATION'), ('Guinea', 'LOCATION')]
# Registro:  11  - Place:  south of the Fiji Islands
# [('south', 'O'), ('of', 'O'), ('the', 'O'), ('Fiji', 'LOCATION'), ('Islands', 'LOCATION')]
# Registro:  12  - Place:  Mindanao, Philippines
# [('Mindanao,', 'O'), ('Philippines', 'LOCATION')]
# Registro:  13  - Place:  offshore Valparaiso, Chile
# [('offshore', 'O'), ('Valparaiso,', 'O'), ('Chile', 'LOCATION')]
# Registro:  14  - Place:  northern Mid-Atlantic Ridge
# [('northern', 'O'), ('Mid-Atlantic', 'LOCATION'), ('Ridge', 'LOCATION')]
# Registro:  15  - Place:  Mid-Indian Ridge
# [('Mid-Indian', 'O'), ('Ridge', 'O')]
# Registro:  16  - Place:  Kuril Islands
# [('Kuril', 'LOCATION'), ('Islands', 'LOCATION')]
# Registro:  17  - Place:  Ascension Island region
# [('Ascension', 'LOCATION'), ('Island', 'LOCATION'), ('region', 'O')]
# Registro:  18  - Place:  southern Sumatra, Indonesia
# [('southern', 'O'), ('Sumatra,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  19  - Place:  Hindu Kush region, Afghanistan
# [('Hindu', 'O'), ('Kush', 'O'), ('region,', 'O'), ('Afghanistan', 'LOCATION')]
# Registro:  20  - Place:  southwestern Ryukyu Islands, Japan
# [('southwestern', 'O'), ('Ryukyu', 'O'), ('Islands,', 'O'), ('Japan', 'LOCATION')]
# Registro:  21  - Place:  Izu Islands, Japan region
# [('Izu', 'O'), ('Islands,', 'O'), ('Japan', 'LOCATION'), ('region', 'O')]
# Registro:  22  - Place:  Myanmar
# [('Myanmar', 'O')]
# Registro:  23  - Place:  Luzon, Philippines
# [('Luzon,', 'O'), ('Philippines', 'LOCATION')]
# Registro:  24  - Place:  Kepulauan Talaud, Indonesia
# [('Kepulauan', 'O'), ('Talaud,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  25  - Place:  Bougainville region, Papua New Guinea
# [('Bougainville', 'O'), ('region,', 'O'), ('Papua', 'LOCATION'), ('New', 'LOCATION'), ('Guinea', 'LOCATION')]
# Registro:  26  - Place:  Ryukyu Islands, Japan
# [('Ryukyu', 'O'), ('Islands,', 'O'), ('Japan', 'LOCATION')]
# Registro:  27  - Place:  Kermadec Islands region
# [('Kermadec', 'O'), ('Islands', 'O'), ('region', 'O')]
# Registro:  28  - Place:  southern Iran
# [('southern', 'O'), ('Iran', 'LOCATION')]
# Registro:  29  - Place:  South Island of New Zealand
# [('South', 'LOCATION'), ('Island', 'LOCATION'), ('of', 'LOCATION'), ('New', 'LOCATION'), ('Zealand', 'LOCATION')]
# Registro:  30  - Place:  Mariana Islands region
# [('Mariana', 'LOCATION'), ('Islands', 'LOCATION'), ('region', 'O')]
# Registro:  31  - Place:  Tonga region
# [('Tonga', 'LOCATION'), ('region', 'O')]
# Registro:  32  - Place:  Tarapaca, Chile
# [('Tarapaca,', 'O'), ('Chile', 'LOCATION')]
# Registro:  33  - Place:  Taiwan region
# [('Taiwan', 'LOCATION'), ('region', 'O')]
# Registro:  34  - Place:  Mindoro, Philippines
# [('Mindoro,', 'O'), ('Philippines', 'LOCATION')]
# Registro:  35  - Place:  off the coast of Oregon
# [('off', 'O'), ('the', 'O'), ('coast', 'O'), ('of', 'O'), ('Oregon', 'LOCATION')]
# Registro:  36  - Place:  near the west coast of Honshu, Japan
# [('near', 'O'), ('the', 'O'), ('west', 'O'), ('coast', 'O'), ('of', 'O'), ('Honshu,', 'O'), ('Japan', 'LOCATION')]
# Registro:  37  - Place:  Libertador General Bernardo O'Higgins, Chile
# [('Libertador', 'O'), ('General', 'O'), ('Bernardo', 'PERSON'), ("O'Higgins,", 'PERSON'), ('Chile', 'LOCATION')]
# Registro:  38  - Place:  Banda Sea
# [('Banda', 'LOCATION'), ('Sea', 'LOCATION')]
# Registro:  39  - Place:  southern Mid-Atlantic Ridge
# [('southern', 'O'), ('Mid-Atlantic', 'LOCATION'), ('Ridge', 'LOCATION')]
# Registro:  40  - Place:  southern Xinjiang, China
# [('southern', 'O'), ('Xinjiang,', 'O'), ('China', 'LOCATION')]
# Registro:  41  - Place:  Guam region
# [('Guam', 'O'), ('region', 'O')]
# Registro:  42  - Place:  offshore El Salvador
# [('offshore', 'O'), ('El', 'LOCATION'), ('Salvador', 'LOCATION')]
# Registro:  43  - Place:  Solomon Islands
# [('Solomon', 'LOCATION'), ('Islands', 'LOCATION')]
# Registro:  44  - Place:  Simeulue, Indonesia
# [('Simeulue,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  45  - Place:  Santa Cruz Islands
# [('Santa', 'LOCATION'), ('Cruz', 'LOCATION'), ('Islands', 'LOCATION')]
# Registro:  46  - Place:  Andreanof Islands, Aleutian Islands, Alaska
# [('Andreanof', 'O'), ('Islands,', 'O'), ('Aleutian', 'O'), ('Islands,', 'O'), ('Alaska', 'LOCATION')]
# Registro:  47  - Place:  Java, Indonesia
# [('Java,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  48  - Place:  North Island of New Zealand
# [('North', 'LOCATION'), ('Island', 'LOCATION'), ('of', 'LOCATION'), ('New', 'LOCATION'), ('Zealand', 'LOCATION')]
# Registro:  49  - Place:  offshore Bio-Bio, Chile
# [('offshore', 'O'), ('Bio-Bio,', 'O'), ('Chile', 'LOCATION')]
# Registro:  50  - Place:  Jujuy, Argentina
# [('Jujuy,', 'O'), ('Argentina', 'LOCATION')]
# Registro:  51  - Place:  Nias region, Indonesia
# [('Nias', 'O'), ('region,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  52  - Place:  south of the Kermadec Islands
# [('south', 'O'), ('of', 'O'), ('the', 'O'), ('Kermadec', 'LOCATION'), ('Islands', 'LOCATION')]
# Registro:  53  - Place:  offshore Chiapas, Mexico
# [('offshore', 'O'), ('Chiapas,', 'O'), ('Mexico', 'LOCATION')]
# Registro:  54  - Place:  northern Sumatra, Indonesia
# [('northern', 'O'), ('Sumatra,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  55  - Place:  off the east coast of the North Island of New Zealand
# [('off', 'O'), ('the', 'O'), ('east', 'O'), ('coast', 'O'), ('of', 'O'), ('the', 'O'), ('North', 'LOCATION'), ('Island', 'LOCATION'), ('of', 'LOCATION'), ('New', 'LOCATION'), ('Zealand', 'LOCATION')]
# Registro:  56  - Place:  near the coast of Nicaragua
# [('near', 'O'), ('the', 'O'), ('coast', 'O'), ('of', 'O'), ('Nicaragua', 'LOCATION')]
# Registro:  57  - Place:  Carlsberg Ridge
# [('Carlsberg', 'ORGANIZATION'), ('Ridge', 'ORGANIZATION')]
# Registro:  58  - Place:  Kermadec Islands, New Zealand
# [('Kermadec', 'O'), ('Islands,', 'O'), ('New', 'LOCATION'), ('Zealand', 'LOCATION')]
# Registro:  59  - Place:  southeast of the Loyalty Islands
# [('southeast', 'O'), ('of', 'O'), ('the', 'O'), ('Loyalty', 'LOCATION'), ('Islands', 'LOCATION')]
# Registro:  60  - Place:  Papua, Indonesia
# [('Papua,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  61  - Place:  Pacific-Antarctic Ridge
# [('Pacific-Antarctic', 'O'), ('Ridge', 'O')]
# Registro:  62  - Place:  Ceram Sea, Indonesia
# [('Ceram', 'O'), ('Sea,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  63  - Place:  near the east coast of the Kamchatka Peninsula, Russia
# [('near', 'O'), ('the', 'O'), ('east', 'O'), ('coast', 'O'), ('of', 'O'), ('the', 'O'), ('Kamchatka', 'LOCATION'), ('Peninsula,', 'LOCATION'), ('Russia', 'LOCATION')]
# Registro:  64  - Place:  New Ireland region, Papua New Guinea
# [('New', 'LOCATION'), ('Ireland', 'LOCATION'), ('region,', 'O'), ('Papua', 'LOCATION'), ('New', 'LOCATION'), ('Guinea', 'LOCATION')]
# Registro:  65  - Place:  Kepulauan Babar, Indonesia
# [('Kepulauan', 'O'), ('Babar,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  66  - Place:  Reykjanes Ridge
# [('Reykjanes', 'O'), ('Ridge', 'O')]
# Registro:  67  - Place:  Molucca Sea
# [('Molucca', 'LOCATION'), ('Sea', 'LOCATION')]
# Registro:  68  - Place:  near the north coast of New Guinea, Papua New Guinea
# [('near', 'O'), ('the', 'O'), ('north', 'O'), ('coast', 'O'), ('of', 'O'), ('New', 'O'), ('Guinea,', 'O'), ('Papua', 'LOCATION'), ('New', 'LOCATION'), ('Guinea', 'LOCATION')]
# Registro:  69  - Place:  southern East Pacific Rise
# [('southern', 'O'), ('East', 'LOCATION'), ('Pacific', 'LOCATION'), ('Rise', 'LOCATION')]
# Registro:  70  - Place:  near the north coast of Papua, Indonesia
# [('near', 'O'), ('the', 'O'), ('north', 'O'), ('coast', 'O'), ('of', 'O'), ('Papua,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  71  - Place:  Kepulauan Barat Daya, Indonesia
# [('Kepulauan', 'O'), ('Barat', 'O'), ('Daya,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  72  - Place:  Atacama, Chile
# [('Atacama,', 'O'), ('Chile', 'LOCATION')]
# Registro:  73  - Place:  Auckland Islands, New Zealand region
# [('Auckland', 'LOCATION'), ('Islands,', 'O'), ('New', 'LOCATION'), ('Zealand', 'LOCATION'), ('region', 'O')]
# Registro:  74  - Place:  Laos
# [('Laos', 'O')]
# Registro:  75  - Place:  Amurskaya Oblast', Russia
# [('Amurskaya', 'O'), ("Oblast',", 'O'), ('Russia', 'LOCATION')]
# Registro:  76  - Place:  Rat Islands, Aleutian Islands, Alaska
# [('Rat', 'O'), ('Islands,', 'O'), ('Aleutian', 'O'), ('Islands,', 'O'), ('Alaska', 'LOCATION')]
# Registro:  77  - Place:  Vancouver Island, Canada region
# [('Vancouver', 'O'), ('Island,', 'O'), ('Canada', 'LOCATION'), ('region', 'O')]
# Registro:  78  - Place:  central Mid-Atlantic Ridge
# [('central', 'O'), ('Mid-Atlantic', 'LOCATION'), ('Ridge', 'LOCATION')]
# Registro:  79  - Place:  Sumbawa region, Indonesia
# [('Sumbawa', 'O'), ('region,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  80  - Place:  Guatemala
# [('Guatemala', 'LOCATION')]
# Registro:  81  - Place:  east of the Kuril Islands
# [('east', 'O'), ('of', 'O'), ('the', 'O'), ('Kuril', 'LOCATION'), ('Islands', 'LOCATION')]
# Registro:  82  - Place:  Antofagasta, Chile
# [('Antofagasta,', 'O'), ('Chile', 'LOCATION')]
# Registro:  83  - Place:  Gulf of Aden
# [('Gulf', 'O'), ('of', 'O'), ('Aden', 'LOCATION')]
# Registro:  84  - Place:  offshore Guatemala
# [('offshore', 'O'), ('Guatemala', 'LOCATION')]
# Registro:  85  - Place:  Halmahera, Indonesia
# [('Halmahera,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  86  - Place:  Greenland Sea
# [('Greenland', 'LOCATION'), ('Sea', 'LOCATION')]
# Registro:  87  - Place:  Flores Sea
# [('Flores', 'O'), ('Sea', 'O')]
# Registro:  88  - Place:  Eritrea
# [('Eritrea', 'LOCATION')]
# Registro:  89  - Place:  Kepulauan Sangihe, Indonesia
# [('Kepulauan', 'O'), ('Sangihe,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  90  - Place:  Balleny Islands region
# [('Balleny', 'O'), ('Islands', 'O'), ('region', 'O')]
# Registro:  91  - Place:  Eritrea - Ethiopia region
# [('Eritrea', 'LOCATION'), ('-', 'O'), ('Ethiopia', 'LOCATION'), ('region', 'O')]
# Registro:  92  - Place:  Bali Sea
# [('Bali', 'LOCATION'), ('Sea', 'LOCATION')]
# Registro:  93  - Place:  Kepulauan Tanimbar, Indonesia
# [('Kepulauan', 'O'), ('Tanimbar,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  94  - Place:  El Salvador
# [('El', 'O'), ('Salvador', 'O')]
# Registro:  95  - Place:  Greece
# [('Greece', 'LOCATION')]
# Registro:  96  - Place:  Admiralty Islands region, Papua New Guinea
# [('Admiralty', 'O'), ('Islands', 'O'), ('region,', 'O'), ('Papua', 'LOCATION'), ('New', 'LOCATION'), ('Guinea', 'LOCATION')]
# Registro:  97  - Place:  Colombia
# [('Colombia', 'LOCATION')]
# Registro:  98  - Place:  Ecuador
# [('Ecuador', 'O')]
# Registro:  99  - Place:  Hokkaido, Japan region
# [('Hokkaido,', 'O'), ('Japan', 'LOCATION'), ('region', 'O')]
# Registro:  100  - Place:  Bali region, Indonesia
# [('Bali', 'LOCATION'), ('region,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  101  - Place:  Chagos Archipelago region
# [('Chagos', 'O'), ('Archipelago', 'O'), ('region', 'O')]
# Registro:  102  - Place:  Easter Island region
# [('Easter', 'LOCATION'), ('Island', 'LOCATION'), ('region', 'O')]
# Registro:  103  - Place:  Jan Mayen Island region
# [('Jan', 'O'), ('Mayen', 'LOCATION'), ('Island', 'LOCATION'), ('region', 'O')]
# Registro:  104  - Place:  Hawaii region, Hawaii
# [('Hawaii', 'O'), ('region,', 'O'), ('Hawaii', 'LOCATION')]
# Registro:  105  - Place:  Ethiopia
# [('Ethiopia', 'LOCATION')]
# Registro:  106  - Place:  Costa Rica
# [('Costa', 'LOCATION'), ('Rica', 'LOCATION')]
# Registro:  107  - Place:  Andaman Islands, India region
# [('Andaman', 'O'), ('Islands,', 'O'), ('India', 'LOCATION'), ('region', 'O')]
# Registro:  108  - Place:  Honduras
# [('Honduras', 'LOCATION')]
# Registro:  109  - Place:  Kashmir-Xinjiang border region
# [('Kashmir-Xinjiang', 'O'), ('border', 'O'), ('region', 'O')]
# Registro:  110  - Place:  western Indian-Antarctic Ridge
# [('western', 'O'), ('Indian-Antarctic', 'O'), ('Ridge', 'O')]
# Registro:  111  - Place:  Kodiak Island region, Alaska
# [('Kodiak', 'LOCATION'), ('Island', 'LOCATION'), ('region,', 'O'), ('Alaska', 'LOCATION')]
# Registro:  112  - Place:  north of Ascension Island
# [('north', 'O'), ('of', 'O'), ('Ascension', 'LOCATION'), ('Island', 'LOCATION')]
# Registro:  113  - Place:  central East Pacific Rise
# [('central', 'O'), ('East', 'LOCATION'), ('Pacific', 'LOCATION'), ('Rise', 'LOCATION')]
# Registro:  114  - Place:  central Peru
# [('central', 'O'), ('Peru', 'LOCATION')]
# Registro:  115  - Place:  east of the North Island of New Zealand
# [('east', 'O'), ('of', 'O'), ('the', 'O'), ('North', 'LOCATION'), ('Island', 'LOCATION'), ('of', 'O'), ('New', 'LOCATION'), ('Zealand', 'LOCATION')]
# Registro:  116  - Place:  eastern Sea of Japan
# [('eastern', 'O'), ('Sea', 'O'), ('of', 'O'), ('Japan', 'LOCATION')]
# Registro:  117  - Place:  near the coast of Ecuador
# [('near', 'O'), ('the', 'O'), ('coast', 'O'), ('of', 'O'), ('Ecuador', 'LOCATION')]
# Registro:  118  - Place:  near the coast of central Peru
# [('near', 'O'), ('the', 'O'), ('coast', 'O'), ('of', 'O'), ('central', 'O'), ('Peru', 'LOCATION')]
# Registro:  119  - Place:  near the east coast of Koryakskiy Avtonomnyy Okrug, Russia
# [('near', 'O'), ('the', 'O'), ('east', 'O'), ('coast', 'O'), ('of', 'O'), ('Koryakskiy', 'O'), ('Avtonomnyy', 'O'), ('Okrug,', 'O'), ('Russia', 'LOCATION')]
# Registro:  120  - Place:  near the north coast of Colombia
# [('near', 'O'), ('the', 'O'), ('north', 'O'), ('coast', 'O'), ('of', 'O'), ('Colombia', 'LOCATION')]
# Registro:  121  - Place:  near the south coast of Honshu, Japan
# [('near', 'O'), ('the', 'O'), ('south', 'O'), ('coast', 'O'), ('of', 'O'), ('Honshu,', 'O'), ('Japan', 'LOCATION')]
# Registro:  122  - Place:  near the south coast of western Honshu, Japan
# [('near', 'O'), ('the', 'O'), ('south', 'O'), ('coast', 'O'), ('of', 'O'), ('western', 'O'), ('Honshu,', 'O'), ('Japan', 'LOCATION')]
# Registro:  123  - Place:  north of Severnaya Zemlya
# [('north', 'O'), ('of', 'O'), ('Severnaya', 'ORGANIZATION'), ('Zemlya', 'ORGANIZATION')]
# Registro:  124  - Place:  Kyrgyzstan
# [('Kyrgyzstan', 'LOCATION')]
# Registro:  125  - Place:  northern Peru
# [('northern', 'O'), ('Peru', 'LOCATION')]
# Registro:  126  - Place:  northern Xinjiang, China
# [('northern', 'O'), ('Xinjiang,', 'O'), ('China', 'LOCATION')]
# Registro:  127  - Place:  northwestern Iran
# [('northwestern', 'O'), ('Iran', 'LOCATION')]
# Registro:  128  - Place:  off the coast of Ecuador
# [('off', 'O'), ('the', 'O'), ('coast', 'O'), ('of', 'O'), ('Ecuador', 'LOCATION')]
# Registro:  129  - Place:  off the west coast of the South Island of New Zealand
# [('off', 'O'), ('the', 'O'), ('west', 'O'), ('coast', 'O'), ('of', 'O'), ('the', 'O'), ('South', 'LOCATION'), ('Island', 'LOCATION'), ('of', 'LOCATION'), ('New', 'LOCATION'), ('Zealand', 'LOCATION')]
# Registro:  130  - Place:  offshore Coquimbo, Chile
# [('offshore', 'O'), ('Coquimbo,', 'O'), ('Chile', 'LOCATION')]
# Registro:  131  - Place:  offshore Northern California
# [('offshore', 'O'), ('Northern', 'LOCATION'), ('California', 'LOCATION')]
# Registro:  132  - Place:  south of Bali, Indonesia
# [('south', 'O'), ('of', 'O'), ('Bali,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  133  - Place:  south of Tonga
# [('south', 'O'), ('of', 'O'), ('Tonga', 'LOCATION')]
# Registro:  134  - Place:  southwest of Sumatra, Indonesia
# [('southwest', 'O'), ('of', 'O'), ('Sumatra,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  135  - Place:  Volcano Islands, Japan region
# [('Volcano', 'O'), ('Islands,', 'O'), ('Japan', 'LOCATION'), ('region', 'O')]
# Registro:  136  - Place:  Vanuatu region
# [('Vanuatu', 'LOCATION'), ('region', 'O')]
# Registro:  137  - Place:  Valparaiso, Chile
# [('Valparaiso,', 'O'), ('Chile', 'LOCATION')]
# Registro:  138  - Place:  Turkey-Iran border region
# [('Turkey-Iran', 'O'), ('border', 'O'), ('region', 'O')]
# Registro:  139  - Place:  Lake Albert region, Uganda
# [('Lake', 'O'), ('Albert', 'O'), ('region,', 'O'), ('Uganda', 'LOCATION')]
# Registro:  140  - Place:  Maule, Chile
# [('Maule,', 'O'), ('Chile', 'LOCATION')]
# Registro:  141  - Place:  Mauritius - Reunion region
# [('Mauritius', 'LOCATION'), ('-', 'O'), ('Reunion', 'O'), ('region', 'O')]
# Registro:  142  - Place:  Mona Passage
# [('Mona', 'O'), ('Passage', 'O')]
# Registro:  143  - Place:  Myanmar-China border region
# [('Myanmar-China', 'O'), ('border', 'O'), ('region', 'O')]
# Registro:  144  - Place:  Nicobar Islands, India region
# [('Nicobar', 'O'), ('Islands,', 'O'), ('India', 'LOCATION'), ('region', 'O')]
# Registro:  145  - Place:  Pagan region, Northern Mariana Islands
# [('Pagan', 'O'), ('region,', 'O'), ('Northern', 'LOCATION'), ('Mariana', 'LOCATION'), ('Islands', 'LOCATION')]
# Registro:  146  - Place:  Panama-Costa Rica border region
# [('Panama-Costa', 'O'), ('Rica', 'LOCATION'), ('border', 'O'), ('region', 'O')]
# Registro:  147  - Place:  Potosi, Bolivia
# [('Potosi,', 'O'), ('Bolivia', 'LOCATION')]
# Registro:  148  - Place:  Sakhalin, Russia
# [('Sakhalin,', 'O'), ('Russia', 'LOCATION')]
# Registro:  149  - Place:  Salta, Argentina
# [('Salta,', 'O'), ('Argentina', 'LOCATION')]
# Registro:  150  - Place:  Samoa Islands region
# [('Samoa', 'LOCATION'), ('Islands', 'LOCATION'), ('region', 'O')]
# Registro:  151  - Place:  Santa Cruz Islands region
# [('Santa', 'LOCATION'), ('Cruz', 'LOCATION'), ('Islands', 'LOCATION'), ('region', 'O')]
# Registro:  152  - Place:  Shikoku, Japan
# [('Shikoku,', 'O'), ('Japan', 'LOCATION')]
# Registro:  153  - Place:  South Africa
# [('South', 'LOCATION'), ('Africa', 'LOCATION')]
# Registro:  154  - Place:  South Indian Ocean
# [('South', 'O'), ('Indian', 'O'), ('Ocean', 'O')]
# Registro:  155  - Place:  Sulawesi, Indonesia
# [('Sulawesi,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  156  - Place:  Sumba region, Indonesia
# [('Sumba', 'O'), ('region,', 'O'), ('Indonesia', 'LOCATION')]
# Registro:  157  - Place:  Taiwan
# [('Taiwan', 'LOCATION')]
# Registro:  158  - Place:  Tajikistan
# [('Tajikistan', 'LOCATION')]
# Registro:  159  - Place:  Trinidad region, Trinidad and Tobago
# [('Trinidad', 'O'), ('region,', 'O'), ('Trinidad', 'LOCATION'), ('and', 'O'), ('Tobago', 'LOCATION')]
# Registro:  160  - Place:  7km NW of The Geysers, CA
# [('7km', 'O'), ('NW', 'O'), ('of', 'O'), ('The', 'O'), ('Geysers,', 'O'), ('CA', 'O')]

# %% [markdown]
# # WORK IN PROGRESS

# %%
fig, ax = plt.subplots(figsize=(16,10))
earthquake.plot(ax=ax, kind='scatter', x='longitude',y='latitude', xlim=[-180,180], ylim=[-90,90])
ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')

# %%
data={'name':['Arica','Santiago','Valdivia'],
      'latitude':[-18.4783,-33.4489,-39.8196],
      'longitude':[-70.3126,-70.6693,-73.2452]}
city = pd.DataFrame(data, columns=['name', 'latitude', 'longitude'])
for i in range(len(city.index)):
    ax.plot(city['longitude'][i], city['latitude'][i], marker='x', color='red', ms=8, mew=2)
    ax.text(city['longitude'][i]+2, city['latitude'][i], city['name'][i], horizontalalignment='left', color='red', size='x-large')
fig

# %%
x=np.asarray(data['longitude'])
y=np.asarray(data['latitude'])
xbins=60
ybins=30
xrange=[-180,180]
yrange=[-90,90]

fig = plt.figure(figsize=(10,6))
hist2D, xedges, yedges = np.histogram2d(x, y, bins=[xbins,ybins], range=[xrange,yrange],normed=False)
hist2D = np.transpose(hist2D)
plt.pcolormesh(xedges, yedges, hist2D, cmap=plt.cm.jet)
plt.xlim(xrange)
plt.ylim(yrange)
ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')
# Out:
# (-90, 90)

# %%
import gmaps
import gmaps.datasets

#Follow the instructions in the following link to obtain a Google API key http://jupyter-gmaps.readthedocs.io/en/latest/authentication.html
gmaps.configure(api_key="")

m = gmaps.Map()

data_gmaps=np.asarray(data[['latitude','longitude','mag']]).tolist()
m.add_layer(gmaps.WeightedHeatmap(data=data_gmaps))
m

# %%
file1='USGS earthquake 2006-2008.csv'
file2='USGS earthquake 2008-2010.csv'
file3='USGS earthquake 2010-2012.csv'
file4='USGS earthquake 2012-2014.csv'
file5='USGS earthquake 2014-2016.csv'
data1=pd.read_csv(file1,header=0,sep=',')
data2=pd.read_csv(file2,header=0,sep=',')
data3=pd.read_csv(file3,header=0,sep=',')
data4=pd.read_csv(file4,header=0,sep=',')
data5=pd.read_csv(file5,header=0,sep=',')

data=pd.concat([data1,data2,data3,data4,data5], ignore_index=True)
data['time']=pd.to_datetime(data['time'], errors='coerce')
data.to_csv('USGS earthquake 2006-2016.csv',index=False)

# %%
import spacy
nlp = spacy.load('en')

for place in earthquake['place'].values:
    text=nlp(place)
    n=len(text.ents)
    if n
    for ent in text.ents:
        print(ent, ent.label, ent.label_)
